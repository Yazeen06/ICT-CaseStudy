# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
db=pd.read_csv('C:/Users/Dell/Downloads/cars_data.csv')

# %%
db
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # Check for the null values present in the dataset.

# %%
db_null=db.isnull().sum()
print("The null values present in the dataset:")
db_null
# Out:
# The null values present in the dataset:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # Plot a bar graph of male vs female buyers participated in the sales

# %%
c=db['Buyer Gender']

# %%
c.value_counts().plot(kind='bar');
plt.xlabel('Buyers')
plt.ylabel('Count')
plt.title('Male VS Female');

# %% [markdown]
# # Find the top 5 cars based on their sales price.

# %%
db
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %%
y=db[['Model','Sale Price']]

# %%
y.sort_values(by='Sale Price',ascending=False).head(5)
# Out:
#           Model  Sale Price
# 5984  Jetta III    99997.65
# 1270         A6    99991.91
# 3460         LX    99983.38
# 9032       MX-6    99978.17
# 302          ES    99973.44

# %% [markdown]
# # Find the least 5 cars based on their Resell price.

# %%
x=db[['Model','Resell Price']]

# %%
x.sort_values(by='Resell Price',ascending=True).head(5)
# Out:
#             Model  Resell Price
# 2446         1500       2000.84
# 4933  Savana 1500       2005.44
# 566            XF       2014.09
# 2538       3000GT       2017.24
# 5869          G37       2017.83
